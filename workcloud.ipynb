# %%
# prompt: read csv from C:\Users\Alwin Ashraf\Desktop\preproces\deep learning test\vader
import pandas as pd
data_file = pd.read_csv(r"C:\Users\Alwin Ashraf\Desktop\fyp dashboard\dataset for dashboarding.csv")

# %%
pip install wordcloud
# Out:
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    -------------------------------- ------- 245.8/300.2 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 3.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# prompt: make a wordcloud from "preprocess tweet" column  and seperate by "sentiment" column  between positive and negative

from wordcloud import WordCloud
import matplotlib.pyplot as plt

positive_words = " ".join(data_file[data_file.sentiment == "positive"]["preprocess tweet"].tolist())
negative_words = " ".join(data_file[data_file.sentiment == "negative"]["preprocess tweet"].tolist())

# Generate word clouds
positive_wordcloud = WordCloud(width=800, height=600).generate(positive_words)
negative_wordcloud = WordCloud(width=800, height=600).generate(negative_words)

# Plot the word clouds
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(positive_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Positive")

plt.subplot(1, 2, 2)
plt.imshow(negative_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Negative")

plt.show()
